# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/cenkerarin/lotus/5ML/datasets/5ML_example_datasets/Ship_Performance_Dataset.csv')
